# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns

# %%
reader2 = pd.read_csv('searches.csv', nrows=100000, delimiter='^')

# %%
reader2.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure      ...        \
# 0    TXL         AUH          1           2           TXL      ...
# 1    ATH         MIL          0           1           ATH      ...
# 2    ICT         SFO          1           2           ICT      ...
# 3    RNB         ARN          0           1           RNB      ...
# 4    OSL         MAD          1           2           OSL      ...
#
#   Seg6Arrival Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
reader2.columns
# Out:
# Index(['Date', 'Time', 'TxnCode', 'OfficeID', 'Country', 'Origin',
#        'Destination', 'RoundTrip', 'NbSegments', 'Seg1Departure',
#        'Seg1Arrival', 'Seg1Date', 'Seg1Carrier', 'Seg1BookingCode',
#        'Seg2Departure', 'Seg2Arrival', 'Seg2Date', 'Seg2Carrier',
#        'Seg2BookingCode', 'Seg3Departure', 'Seg3Arrival', 'Seg3Date',
#        'Seg3Carrier', 'Seg3BookingCode', 'Seg4Departure', 'Seg4Arrival',
#        'Seg4Date', 'Seg4Carrier', 'Seg4BookingCode', 'Seg5Departure',
#        'Seg5Arrival', 'Seg5Date', 'Seg5Carrier', 'Seg5BookingCode',
#        'Seg6Departure', 'Seg6Arrival', 'Seg6Date', 'Seg6Carrier',
#        'Seg6BookingCode', 'From', 'IsPublishedForNeg', 'IsFromInternet',
#        'IsFromVista', 'TerminalID', 'InternetOffice'],
#       dtype='object')

# %%
reader2['Destination'].str.len()
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
# 5        3
# 6        3
# 7        3
# 8        3
# 9        3
# 10       3
# 11       3
# 12       3
# 13       3
# 14       3
# 15       3
# 16       3
# 17       3
# 18       3
# 19       3
# 20       3
# 21       3
# 22       3
# 23       3
# 24       3
# 25       3
# 26       3
# 27       3
# 28       3
# 29       3
#         ..
# 99970    3
# 99971    3
# 99972    3
# 99973    3
# 99974    3
# 99975    3
# 99976    3
# 99977    3
# 99978    3
# 99979    3
# 99980    3
# 99981    3
# 99982    3
# 99983    3
# 99984    3
# 99985    3
# 99986    3
# 99987    3
# 99988    3
# 99989    3
# 99990    3
# 99991    3
# 99992    3
# 99993    3
# 99994    3
# 99995    3
# 99996    3
# 99997    3
# 99998    3
# 99999    3
# Name: Destination, Length: 100000, dtype: int64

# %%
fly_to_malaga=reader2[reader2['Destination']=='AGP']

# %%
fly_to_malaga.head()
# Out:
#            Date      Time TxnCode                          OfficeID Country  \
# 93   2013-01-01  20:15:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 147  2013-01-01  15:35:53     MPT  63d35a15724f95939e6d0dd0ca39be16      DE
# 242  2013-01-01  18:47:50     MPT  22cf15984f4b13ed8f513a42324666d1      FR
# 458  2013-01-01  12:43:44     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 674  2013-01-01  19:47:16     MPT  b5eea863a84ba9b21115d5e90bca9157      FI
#
#     Origin Destination  RoundTrip  NbSegments Seg1Departure      ...        \
# 93     FRA         AGP          1           2           FRA      ...
# 147    HHN         AGP          0           1           HHN      ...
# 242    GVA         AGP          1           2           GVA      ...
# 458    DUS         AGP          0           1           DUS      ...
# 674    HEL         AGP          1           2           HEL      ...
#
#     Seg6Arrival Seg6Date Seg6Carrier Seg6BookingCode    From  \
# ...

# %%
prueba= pd.to_datetime(fly_to_malaga['Date'])

# %%
fly_to_malaga['month']=prueba.dt.month
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
fly_to_malaga.groupby('month').count()
# Out:
#        Date  Time  TxnCode  OfficeID  Country  Origin  Destination  RoundTrip  \
# month
# 1       169   169      169       169      169     169          169        169
# 2       147   147      147       147      147     147          147        147
# 3       187   187      187       187      187     187          187        187
# 4        31    31       31        31       31      31           31         31
#
#        NbSegments  Seg1Departure       ...        Seg6Arrival  Seg6Date  \
# month                                  ...
# 1             169            169       ...                  0         0
# 2             147            147       ...                  1         1
# 3             187            187       ...                  0         0
# 4              31             31       ...                  0         0
#
#        Seg6Carrier  Seg6BookingCode  From  IsPublishedForNeg  IsFromInternet  \
# month
# ...

# %%
prueba.dt.month
# Out:
# 93       1
# 147      1
# 242      1
# 458      1
# 674      1
# 835      1
# 904      1
# 1414     1
# 1531     1
# 1936     1
# 1974     1
# 2368     1
# 2500     1
# 2560     1
# 2685     1
# 2925     1
# 3304     1
# 3327     1
# 3337     1
# 3663     1
# 3858     1
# 4062     1
# 4115     1
# 4232     1
# 4628     1
# 5409     1
# 5672     1
# 5903     1
# 5930     1
# 6810     1
#         ..
# 90617    4
# 90629    4
# 90902    4
# 90945    4
# 90978    4
# 91366    4
# 91576    4
# 92104    4
# 92136    4
# 92359    4
# 92685    4
# 92756    4
# 93654    4
# 94645    4
# 95458    4
# 95600    4
# 95866    4
# 96044    4
# 96753    4
# 96914    4
# 97045    4
# 97217    4
# 97608    4
# 98043    4
# 98149    4
# 98301    4
# 99103    4
# 99214    4
# 99814    4
# 99919    4
# Name: Date, Length: 534, dtype: int64

# %%
sns.pointplot(data=fly_to_malaga,y='month', x='month', hue='Destination', estimator=np.count_nonzero)
#sns.barplot(data=penguins,x='bill_length_mm', y='species')
#plt.plot(x,y)
# plt.legend('ABCDEF',ncol=2,loc='upper left')

# %%
fly_to_MBM=reader2[reader2.Destination.isin(['AGP','BCN','MAD'])]
# filtro los tres aeropuertos de interes

# %%
fly_to_MBM
# Out:
#              Date      Time TxnCode                          OfficeID Country  \
# 4      2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
# 93     2013-01-01  20:15:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 113    2013-01-01  23:40:53     FXX  0028c46214bc260eb3011510a898cd42      ES
# 147    2013-01-01  15:35:53     MPT  63d35a15724f95939e6d0dd0ca39be16      DE
# 151    2013-01-01  10:46:21     MPT  50c54b52322080d2c257390f714f91bd      ES
# 165    2013-01-01  03:40:25     MPT  f4b923424d840c9128df27b5242feffa      US
# 177    2013-01-01  11:26:34     MPT  3ac5426dd4f6bb8de28349c7b77e1ee4      IT
# 186    2013-01-01  09:46:07     MPT  61880d6e0141d7ec9659ef77e29aab01      DK
# 188    2013-01-01  02:07:17     CAL  b9c9a14cb66d19de74865613593d2e95      MA
# 208    2013-01-01  15:58:35     FFP  99a5fa66a00828db9727aea7ebc6ae74      DE
# 229    2013-01-01  15:18:55     MPT  03a4fc8b3cd31d6d5b5d7b86d20f4af8      DE
# ...

# %%
prueba= pd.to_datetime(fly_to_MBM['Date'])
#Convierte en campo de tiempo al campo Date

# %%
fly_to_MBM['month']=prueba.dt.month
#Incorporo el campo al dataframe
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.pointplot(data=fly_to_MBM,y='month', x='month', hue='Destination', estimator=np.count_nonzero)

# %%
reader = pd.read_csv('searches.csv', chunksize=1000, delimiter='^')
# es un buffer a memoria


df = None

for chunk in reader:

   df = chunk

   break
# a través del bucle hacemos un dataframe del buffer
df.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure      ...        \
# 0    TXL         AUH          1           2           TXL      ...
# 1    ATH         MIL          0           1           ATH      ...
# 2    ICT         SFO          1           2           ICT      ...
# 3    RNB         ARN          0           1           RNB      ...
# 4    OSL         MAD          1           2           OSL      ...
#
#   Seg6Arrival Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
reader2 = pd.read_csv('searches.csv', chunksize=1000, delimiter='^')

def read_sum(pointer):   

    df = None

    df2 = None
    
    df3 = pd.DataFrame()
    
    for chunk in pointer:

        df = chunk

        df2 = df[['Date','Destination']][df.Destination.isin(['AGP','BCN','MAD'])]

        df3 = df3.append(df2)

        del df

    return df3

# %%
def result(fly_to_MBM):
    fly_to_MBM = (fly_to_MBM)
    prueba= pd.to_datetime(fly_to_MBM['Date'])
    fly_to_MBM['month']=prueba.dt.month
    return sns.pointplot(data=fly_to_MBM,y='month', x='month', hue='Destination', estimator=np.count_nonzero)

# %%
result(a)

# %%
prueba= pd.to_datetime(a['Date'])

# %%
b = pd.DataFrame(a)

# %%
b.columns
# Out:
# Index([], dtype='object')

# %%
fly_to_malaga=reader2[['Date','Destination']][reader2.Destination.isin(['AGP','BCN','MAD'])]

# %%
prueba
# Out:
# 4          2013-01-01
# 93         2013-01-01
# 113        2013-01-01
# 147        2013-01-01
# 151        2013-01-01
# 165        2013-01-01
# 177        2013-01-01
# 186        2013-01-01
# 188        2013-01-01
# 208        2013-01-01
# 229        2013-01-01
# 242        2013-01-01
# 253        2013-01-01
# 322        2013-01-01
# 365        2013-01-01
# 375        2013-01-01
# 406        2013-01-01
# 458        2013-01-01
# 481        2013-01-01
# 500        2013-01-01
# 509        2013-01-01
# 541        2013-01-01
# 593        2013-01-01
# 606        2013-01-01
# 618        2013-01-01
# 623        2013-01-01
# 628        2013-01-01
# 633        2013-01-01
# 641        2013-01-01
# 674        2013-01-01
#               ...
# 20389101   2013-10-12
# 20389110   2013-10-12
# 20389160   2013-10-12
# 20389172   2013-10-12
# 20389185   2013-10-12
# 20389206   2013-10-12
# 20389343   2013-10-13
# 20389409   2013-10-13
# 20389437   2013-10-13
# 20389478   2013-10-13
# ...
